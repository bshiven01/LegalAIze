# %%
#!pip install datasets

# %%
#Load the Dataset
from datasets import load_dataset
import pandas as pd
import random
import re
import torch
import os
import torch.nn.functional as F

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# %%
# Load the 'us_bills'
dataset = load_dataset("pile-of-law/pile-of-law", "us_bills")
# Out:
# Loading Dataset Infos from /Users/urvimidha/.cache/huggingface/modules/datasets_modules/datasets/pile-of-law--pile-of-law/c1090502f95031ebfad49ede680394da5532909fa46b7a0452be8cddecc9fa60
# Overwrite dataset info from restored data version if exists.
# Loading Dataset info from /Users/urvimidha/.cache/huggingface/datasets/pile-of-law___pile-of-law/us_bills/0.0.0/c1090502f95031ebfad49ede680394da5532909fa46b7a0452be8cddecc9fa60
# Found cached dataset pile-of-law (/Users/urvimidha/.cache/huggingface/datasets/pile-of-law___pile-of-law/us_bills/0.0.0/c1090502f95031ebfad49ede680394da5532909fa46b7a0452be8cddecc9fa60)
# Loading Dataset info from /Users/urvimidha/.cache/huggingface/datasets/pile-of-law___pile-of-law/us_bills/0.0.0/c1090502f95031ebfad49ede680394da5532909fa46b7a0452be8cddecc9fa60

# %%
len(set(dataset['train']['text']))
# Out:
# 84362

# %%
def clean_text(bills):
    clean_bills = []
    for bill in bills:
      # Remove all newline and tab characters
      text = bill.replace('\n', ' ').replace('\t', ' ')
      # Remove exactly three lowercase letters helps in (removing roman numeral numbering )
      text = re.sub(r'\[([a-z]{1,3})\]', ' ', text, flags=re.IGNORECASE)
      clean_bills.append(text.lower())

    return clean_bills

# %%
print(clean_text(dataset['train']['text'][:2]))
# Out:
# ['    113 s2875 is: national guard investigations transparency and improvement act of 2014 u.s. senate 2014-09-18 text/xml en pursuant to title 17 section 105 of the united states code, this file is not subject to copyright protection and is in the public domain.      ii   113th congress2d session   s. 2875   in the senate of the united states       september 18, 2014    mr. begich introduced the following bill; which was read twice and referred to the committee on armed services      a bill   to codify in law the establishment and duties of the office of complex administrative     investigations in the national guard bureau, and for other purposes.    1.short titlethis act may be cited as the national guard investigations transparency and improvement act of 2014.2.codification in law of establishment and duties of the office of complex administrative     investigations in the national guard bureau(a)in generalthere is in the office of the chief of the national guard bureau the office of complex     administrative investigations (in this section referred to as the office).(b)direction and supervisionthe office shall be under the direction and supervision of the chief of the national guard     bureau.(c)duties(1)in generalthe duties of the office shall be to undertake complex administrative investigations of matters     relating to members of the national guard when in state status, including     investigations of sexual assault involving a member of the national guard     in such status, upon the request of any of the following:(a)the chief of the national guard bureau.(b)an adjutant general of a state or territory or the district of columbia.(c)the governor  of a state or territory, or the commanding general of the national guard of the     district of columbia.(2)complex administrative investigationsfor purposes of this subsection, a complex administrative investigation is any investigation (as     specified by the chief of the national guard bureau for purposes     of this section) involving factors giving rise to unusual complexity in     investigation, including the following:(a)questions of jurisdiction between the united states and a state or territory.(b)matters requiring specialized training among investigating officers.(c)matters raising the need for an independent investigation in order to ensure fairness and     impartiality in investigation.(3)matters relating to members of the national guard in state statusthe determination whether or not a matter relates to a member of the national guard when in state     status for purposes of this section shall be made by the chief of     the national guard bureau in accordance with criteria specified by the     chief of the national guard bureau  for purposes of this section.(d)chief of national  guard bureau treatment of final reportsthe chief of the national guard bureau shall  treat any final report of the office on a matter      under this section as if such report were the report of an inspector     general of the department of defense or a military department on such     matter.(e)reports to congress(1)submittal of final reports to congressional delegationsupon the adoption by the office of a final report on an investigation undertaken by the office     pursuant to this section, the chief of the national guard bureau shall     submit such report (with any personally identifying information     appropriately redacted) to the members of congress from the state or     territory concerned.(2)annual reportsthe chief of the national guard bureau shall submit to congress each year a report on the     investigations undertaken by the office pursuant to this section during     the preceding year. each report shall include, for the year covered by     such report,  the following:(a)a summary description of the     investigations undertaken during such year,     including any trends in matters subject to investigation and in findings     as a result of investigations.(b)informatio ...

# %%
# Load GPT-2 model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")
# Out:
# /Users/urvimidha/anaconda3/lib/python3.11/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
def predict_next_word(text, actual_next_word, model=model, tokenizer=tokenizer, top_k=3,):
    """
    Predicts the next word for a given text using GPT-2.
    """
    total_log_prob = 0.0
    input_ids = text

    #### print("Predict next word, input shape: ", input_ids.shape)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    #print(device)
    #print("input_ids device: ", input_ids.device)

    with torch.no_grad():
        outputs = model(input_ids.to(device))
        #print("In predict next word Outputs: ", outputs, outputs.logits.shape)
        logits = outputs.logits

#     # Predict the next token (old approach of using only 1 word)
#     predicted_token_id = torch.argmax(logits[:, -1, :], dim=-1).item()
#     predicted_token = tokenizer.decode(predicted_token_id)

    # Predict top k words
    top_k_token_ids = torch.topk(logits[:, -1, :], top_k, dim=-1).indices.squeeze().cpu().tolist()
    top_k_tokens = [tokenizer.decode(token_id) for token_id in top_k_token_ids]
    
    
    #perplexity
    
    log_probs = F.log_softmax(logits[:, -1, :], dim=-1)
    actual_next_word_log_prob = log_probs[0, actual_next_word].item()
    total_log_prob += actual_next_word_log_prob
    total_words= len(input_ids)
    
    # Calculate perplexity
    perplexity = torch.exp(torch.tensor(-total_log_prob / total_words)) if total_words > 0 else float('inf')
    

    return top_k_tokens, perplexity #predicted_token

# %%
def predict_every_n_words(bill_text, bill_number, model, interval_min=20, interval_max=40):
    words = tokenizer.encode(bill_text, return_tensors="pt", truncation=True, max_length=512) #bill_text.split()
    n = words.shape[1]
    results = []

    #### print(words.shape)
    #### print(words)

    random.seed(42)

    # Start from the first 20 words and predict every 20-40 words
    i = 15
    while i < n and i < 512:
        text_chunk = words[:,:i] #' '.join(words[:i])
        actual_next_word = words[:,i]
        #print("Current text chunk: ",  tokenizer.decode(text_chunk[0], skip_special_tokens=True))
        predicted_next_word, perplexity = predict_next_word(text_chunk, model=model, actual_next_word=actual_next_word) #can add parameter top_k=k
        english_actual_next_word = tokenizer.decode(actual_next_word, skip_special_tokens=True)
        
        
        #Modification in prediction for top k
        pred_res = False
        for word in predicted_next_word:
            if word.lower() == english_actual_next_word.lower():
                pred_res = True
       
        res = {
            "bill_number": bill_number,
            "input_text_length": i,
            "actual_next_word": english_actual_next_word,
            "predicted_next_word": predicted_next_word,
            "top_k_word_prediction": pred_res, #english_actual_next_word.lower() == predicted_next_word.lower()
            "top_word_prediction": english_actual_next_word.lower() == predicted_next_word[0].lower(),
            #"perplexity": perplexity
            }
        results.append(res)
        #### print("Appending row: ", res)
        # Move to the next interval of 20-40 words
        interval = random.randint(interval_min, interval_max)
        i += interval

    return results

# %%
def evaluate_bills(bills, model):
    overall_predictions = []
    total_correct = 0
    total_total = 0
    total_correct_topk=0
    

    for idx, bill_text in enumerate(bills):
        print(f"Processing bill {idx} of length {len(bill_text)} characters...")


        results = predict_every_n_words(bill_text, idx, model=model)
        display(pd.DataFrame(results).drop('perplexity', axis=1))

        overall_predictions.extend(results)

        #top k accuracy for the current bill
        correct_predictions_topk = sum(1 for result in results if result['top_k_word_prediction'])
        bill_accuracy_topk = correct_predictions_topk / len(results) if len(results) > 0 else 0
#         tot_perplexity = 0.0
#         for result in results:
#             tot_perplexity += result['perplexity']
#         perplexity = tot_perplexity/len(results)
        
        #accuracy for the current bill
        correct_predictions = sum(1 for result in results if result['top_word_prediction'])
        bill_accuracy = correct_predictions / len(results) if len(results) > 0 else 0

        print(f"Bill {idx} accuracy: {bill_accuracy * 100:.2f}%\n")
        print(f"Bill {idx} top k accuracy: {bill_accuracy_topk * 100:.2f}%\n")
        #print(f"Bill {idx} perplexity: {perplexity:.2f}\n")
        
        total_correct += correct_predictions
        total_total += len(results)
        total_correct_topk += correct_predictions_topk

    df_overall_predictions = pd.DataFrame(overall_predictions) #dataframe
    
    overall_accuracy = total_correct / total_total if total_total > 0 else 0
    overall_accuracy_topk = total_correct_topk / total_total if total_total > 0 else 0
#    avg_perplexity = df_overall_predictions["perplexity"].mean()
    
    print(f"Overall accuracy for all bills: {overall_accuracy * 100:.2f}%")
    print(f"Overall topk accuracy for all bills: {overall_accuracy_topk * 100:.2f}%")
#    print(f"Overall average perplexity all bills: {avg_perplexity:.2f}")
    return df_overall_predictions

# %%
cleaned_validation = clean_text(dataset["validation"]["text"][:15])

# %%
df_predictions_bills = evaluate_bills(cleaned_validation, model)
# Out:
# Processing bill 0 of length 6705 characters...
#     bill_number  input_text_length actual_next_word  \
# 0             0                 15              act
# 1             0                 55              the
# 2             0                 78              the
# 3             0                 98                (
# 4             0                126             penn
# 5             0                153               of
# 6             0                180               of
# 7             0                204                m
# 8             0                227                .
# 9             0                264                m
# 10            0                286                h
# 11            0                324                .
# 12            0                357                ,
# 13            0                378                .
# 14            0                398                ,
# 15            0                420             love
# 16            0                446              aff
# 17            0                473        judiciary
# 18            0                509     jurisdiction
#
#                       predicted_next_word  top_k_word_prediction  \
# 0                              [,, .,  (]                  False
# 1                         [ the, im,  no]                   True
# 2                       [ the, :,  title]                   True
# 3                       [,,  2016,  2015]                  False
# 4                         [ ut,  the,  h]                  False
# 5                   [ man,  lady,  woman]                  False
# 6                             [,,  of, y]                   True
# 7                           [ m,  ,  and]                   True
# 8                              [., ,, \n]                   True
# 9                            [ m,  n,  j]                   True
# 10                           [ m,  p,  j]                  False
# 11                             [., ,, \n]                   True
# 12                         [,,  of,  and]                   True
# 13                             [., ,, \n]                   True
# 14                         [,,  (,  2015]                   True
# 15                           [ b,  d,  c]                  False
# 16                          [af, ris, ab]                  False
# 17        [ Judiciary,  House,  commerce]                   True
# 18  [ jurisdiction,  authority,  meaning]                   True
#
#     top_word_prediction
# 0                 False
# 1                  True
# 2                  True
# 3                 False
# 4                 False
# 5                 False
# 6                 False
# 7                  True
# 8                  True
# 9                  True
# 10                False
# 11                 True
# 12                 True
# 13                 True
# 14                 True
# 15                False
# 16                False
# 17                 True
# 18                 True
# Bill 0 accuracy: 57.89%
#
# Bill 0 top k accuracy: 63.16%
#
# Processing bill 1 of length 48228 characters...
#     bill_number  input_text_length actual_next_word  \
# 0             1                 15              the
# 1             1                 55              the
# 2             1                 78                i
# 3             1                 98           united
# 4             1                126           second
# 5             1                153
# 6             1                180           budget
# 7             1                204              for
# 8             1                227                (
# 9             1                264                1
# 10            1                286              ary
# 11            1                324              201
# 12            1                357                .
# 13            1                378            effic
# 14            1                398          savings
# 15            1                420              500
# 16            1                446                .
# 17            1                473         determin
# 18            1                509           levels
#
#            predicted_next_word  top_k_word_prediction  top_word_prediction
# 0         [ fiscal,  the,  FY]                   True                False
# 1      [ title,  the,  Public]                   True                False
# 2              [ ,  116,  117]                  False                False
# 3   [ United,  united,  state]                   True                 True
# 4     [ second,  third,  next]                   True                 True
# 5     [________________,  , �]                  False                False
# 6                  [ ,  S,  s]                  False                False
# 7            [ for,  of,  and]                   True                 True
# 8                  [ ,  (,  2]                   True                False
# 9                   [1, 01, 2]                   True                 True
# 10           [ for,  and, ary]                   True                False
# 11             [103, 113, 104]                  False                False
# 12                   [., ,, —]                   True                 True
# 13  [ the,  fiscal,  veterans]                  False                False
# 14            [ care,  and, ,]                  False                False
# 15           [ 500,  50,  501]                   True                 True
# 16                   [., ,, —]                   True                 True
# 17            [ of,  in,  and]                  False                False
# 18              [.,  in,  for]                  False                False
# Bill 1 accuracy: 36.84%
#
# Bill 1 top k accuracy: 57.89%
#
# Processing bill 2 of length 4566 characters...
#     bill_number  input_text_length actual_next_word  \
# 0             2                 15              and
# 1             2                 55              and
# 2             2                 78          session
# 3             2                 98
# 4             2                126
# 5             2                153              and
# 6             2                180             with
# 7             2                204
# 8             2                227          service
# 9             2                264              the
# 10            2                286
# 11            2                324
# 12            2                357              and
# 13            2                378       subsection
# 14            2                398
# 15            2                420               be
# 16            2                446              the
# 17            2                473             with
# 18            2                509          dentist
#
#              predicted_next_word  top_k_word_prediction  top_word_prediction
# 0                 [ and,  to, ,]                   True                 True
# 1                   [., ,,  and]                   True                False
# 2     [ s,  reading,  amendment]                  False                False
# 3                [ ,  110,  111]                   True                 True
# 4             [ ,  congress,  1]                   True                 True
# 5                   [ and, ,,  ]                   True                 True
# 6                [ in,  that,  ]                  False                False
# 7                  [ ,  The,  (]                   True                 True
# 8   [ education,  loan,  school]                  False                False
# 9         [ ,  terms,  practice]                  False                False
# 10                    [ ,  ,  *]                   True                 True
# 11                     [ ,  , .]                   True                 True
# 12               [ and,  (,  or]                   True                 True
# 13       [ this,  the,  section]                  False                False
# 14                   [ ,  3,  2]                   True                 True
# 15         [ be,  not,  include]                   True                 True
# 16       [ dentist,  dent,  the]                   True                False
# 17              [ by, ,,  under]                  False                False
# 18    [ dentist,  dental,  dent]                   True                 True
# Bill 2 accuracy: 57.89%
#
# Bill 2 top k accuracy: 68.42%
#
# Processing bill 3 of length 3199 characters...
#     bill_number  input_text_length actual_next_word  \
# 0             3                 15
# 1             3                 55                ,
# 2             3                 78                .
# 3             3                 98
# 4             3                126
# 5             3                153
# 6             3                180
# 7             3                204                a
# 8             3                227         security
# 9             3                264
# 10            3                286       protection
# 11            3                324           issued
# 12            3                357
# 13            3                378                c
# 14            3                398              end
# 15            3                420               of
# 16            3                446
# 17            3                473          include
# 18            3                509
#
#                  predicted_next_word  top_k_word_prediction  \
# 0                        [ ,  of, ,]                   True
# 1                          [),  , ,]                   True
# 2                          [., ., ,]                   True
# 3                         [ ,  , \n]                   True
# 4                        [ ,  m,  t]                   True
# 5                         [ ,  ,  e]                   True
# 6                          [ ,  , .]                   True
# 7                        [ ,  m,  t]                  False
# 8   [ security,  safety,  insurance]                   True
# 9                      [ ,  The,  (]                   True
# 10                [ of,  and,  bill]                  False
# 11                    [ ,  and,  as]                  False
# 12                        [ ,  ,  )]                   True
# 13                       [ c, C,  2]                   True
# 14       [ end,  beginning,  bottom]                   True
# 15                    [ of,  and,  ]                   True
# 16                         [ ,  , .]                   True
# 17            [ any,  title,  other]                  False
# 18                        [ ,  , \n]                   True
#
#     top_word_prediction
# 0                  True
# 1                 False
# 2                  True
# 3                  True
# 4                  True
# 5                  True
# 6                  True
# 7                 False
# 8                  True
# 9                  True
# 10                False
# 11                False
# 12                 True
# 13                False
# 14                 True
# 15                 True
# 16                 True
# 17                False
# 18                 True
# Bill 3 accuracy: 68.42%
#
# Bill 3 top k accuracy: 78.95%
#
# Processing bill 4 of length 7822 characters...
#     bill_number  input_text_length actual_next_word  \
# 0             4                 15                (
# 1             4                 55        liability
# 2             4                 78            trade
# 3             4                 98            other
# 4             4                126                5
# 5             4                153              for
# 6             4                180              the
# 7             4                204              117
# 8             4                227                j
# 9             4                264              oro
# 10            4                286              for
# 11            4                324        equitable
# 12            4                357             ghan
# 13            4                378              for
# 14            4                398              the
# 15            4                420        designate
# 16            4                446                .
# 17            4                473        committee
# 18            4                509          amended
#
#                        predicted_next_word  top_k_word_prediction  \
# 0                              [.,  of, ,]                  False
# 1    [ enforcement,  remed,  compensation]                  False
# 2   [ environmental,  Environmental,  act]                  False
# 3                      [ inj,  to,  other]                   True
# 4                                [), 4, 3]                  False
# 5                    [ to,  for,  provide]                   True
# 6                    [ the,  title,  this]                   True
# 7                                [., .,  ]                  False
# 8                            [ix,  , ____]                  False
# 9                          [oro, or, oros]                   True
# 10                        [ for,  that, ,]                   True
# 11           [ equitable,  equity,  equal]                   True
# 12                         [ghan, gh, gan]                   True
# 13                        [ for,  to,  of]                   True
# 14               [ the,  accordance,  its]                   True
# 15       [ designate,  identify,  certify]                   True
# 16                               [;, ., ,]                   True
# 17                   [ adopted,  and,  of]                  False
# 18               [ amended,  it,  adopted]                   True
#
#     top_word_prediction
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# 5                 False
# 6                  True
# 7                 False
# 8                 False
# 9                  True
# 10                 True
# 11                 True
# 12                 True
# 13                 True
# 14                 True
# 15                 True
# 16                False
# 17                False
# 18                 True
# Bill 4 accuracy: 47.37%
#
# Bill 4 top k accuracy: 63.16%
#
# Processing bill 5 of length 5447 characters...
#     bill_number  input_text_length actual_next_word  \
# 0             5                 15               of
# 1             5                 55                u
# 2             5                 78              the
# 3             5                 98
# 4             5                126             city
# 5             5                153
# 6             5                180              the
# 7             5                204               me
# 8             5                227             most
# 9             5                264             1994
# 10            5                286               of
# 11            5                324           united
# 12            5                357              can
# 13            5                378             host
# 14            5                398              the
# 15            5                420             have
# 16            5                446               20
# 17            5                473           states
# 18            5                509           sports
#
#              predicted_next_word  top_k_word_prediction  top_word_prediction
# 0               [ of,  to,  and]                   True                 True
# 1                 [\n,  The,  (]                  False                False
# 2          [ the,  title,  FIFA]                   True                 True
# 3              [\n,  2018,  The]                  False                False
# 4    [ congress,  United,  same]                  False                False
# 5                    [ en, -, ,]                  False                False
# 6             [ the,  to,  this]                   True                 True
# 7                 [ me,  ,  can]                   True                 True
# 8    [ most,  fastest,  largest]                   True                 True
# 9        [ FIFA,  first,  world]                  False                False
# 10                [,,  for,  of]                   True                False
# 11   [ country,  world,  nation]                  False                False
# 12      [ the,  other,  various]                  False                False
# 13            [ the,  host,  be]                   True                False
# 14             [ me,  the,  can]                   True                False
# 15           [ have,  the,  are]                   True                 True
# 16        [ United,  united,  U]                  False                False
# 17    [ states,  States,  state]                   True                 True
# 18  [ soccer,  sports,  leagues]                   True                False
# Bill 5 accuracy: 36.84%
#
# Bill 5 top k accuracy: 57.89%
#
# Processing bill 6 of length 8875 characters...
#     bill_number  input_text_length  actual_next_word  \
# 0             6                 15
# 1             6                 55               the
# 2             6                 78                 .
# 3             6                 98
# 4             6                126   representatives
# 5             6                153                 a
# 6             6                180
# 7             6                204          national
# 8             6                227             north
# 9             6                264             about
# 10            6                286                 ;
# 11            6                324
# 12            6                357               the
# 13            6                378
# 14            6                398               the
# 15            6                420             peace
# 16            6                446         involving
# 17            6                473       declaration
# 18            6                509            rights
#
#                   predicted_next_word  top_k_word_prediction  \
# 0                    [ the,  God,  a]                  False
# 1                     [ the,  no, im]                   True
# 2                           [., .,  ]                   True
# 3                       [ ,  111,  h]                   True
# 4           [ ,  representatives,  s]                   True
# 5                    [ a,  well,  an]                   True
# 6                          [ ,  ,  t]                   True
# 7   [ linguistic,  ethnic,  cultural]                  False
# 8                   [ ,  and,  north]                   True
# 9                  [ about,  with,  ]                   True
# 10                          [;, ., ,]                   True
# 11                         [ ,  ,   ]                   True
# 12                   [ the,  ,  this]                   True
# 13                      [ ,  a,  the]                   True
# 14                   [ the,  ,  Arab]                   True
# 15        [ solution,  and,  refugee]                  False
# 16                       [;, ,,  and]                  False
# 17         [ beginning,  end,  start]                  False
# 18            [ human,  rights,  the]                   True
#
#     top_word_prediction
# 0                 False
# 1                  True
# 2                  True
# 3                  True
# 4                 False
# 5                  True
# 6                  True
# 7                 False
# 8                 False
# 9                  True
# 10                 True
# 11                 True
# 12                 True
# 13                 True
# 14                 True
# 15                False
# 16                False
# 17                False
# 18                False
# Bill 6 accuracy: 57.89%
#
# Bill 6 top k accuracy: 73.68%
#
# Processing bill 7 of length 8487 characters...
#     bill_number  input_text_length actual_next_word  \
# 0             7                 15
# 1             7                 55          himself
# 2             7                 78
# 3             7                 98         homeland
# 4             7                126
# 5             7                153
# 6             7                180                .
# 7             7                204                (
# 8             7                227
# 9             7                264            after
# 10            7                286                )
# 11            7                324
# 12            7                357                .
# 13            7                378
# 14            7                398               to
# 15            7                420                7
# 16            7                446                (
# 17            7                473                )
# 18            7                509                c
#
#                  predicted_next_word  top_k_word_prediction  \
# 0                        [ ,  of, ,]                   True
# 1                        [ ,  ),  s]                  False
# 2   [ bill,  resolution,  amendment]                  False
# 3               [ the,  commerce,  ]                  False
# 4                         [ ,  , \n]                   True
# 5                      [ ,  The, \n]                   True
# 6                          [., ., ,]                   True
# 7                        [ is, ,, .]                  False
# 8                   [ ,  , ________]                   True
# 9                [ paragraph,  ,  (]                  False
# 10                       [),  u,  U]                   True
# 11                       [ ,  (,  s]                   True
# 12                        [., ,, .,]                   True
# 13                        [ ,  , \n]                   True
# 14     [ and,  provided,  including]                  False
# 15                  [ the,  a,  any]                  False
# 16                       [ (,  ,  1]                   True
# 17                       [), )(, ),]                   True
# 18                        [c,  c, C]                   True
#
#     top_word_prediction
# 0                  True
# 1                 False
# 2                 False
# 3                 False
# 4                  True
# 5                  True
# 6                  True
# 7                 False
# 8                  True
# 9                 False
# 10                 True
# 11                 True
# 12                 True
# 13                 True
# 14                False
# 15                False
# 16                 True
# 17                 True
# 18                 True
# Bill 7 accuracy: 63.16%
#
# Bill 7 top k accuracy: 63.16%
#
# Processing bill 8 of length 16413 characters...
#     bill_number  input_text_length actual_next_word  \
# 0             8                 15
# 1             8                 55
# 2             8                 78            means
# 3             8                 98
# 4             8                126     jurisdiction
# 5             8                153               of
# 6             8                180               by
# 7             8                204                .
# 8             8                227        standards
# 9             8                264               )(
# 10            8                286               13
# 11            8                324
# 12            8                357
# 13            8                378              iii
# 14            8                398               96
# 15            8                420              the
# 16            8                446              are
# 17            8                473                .
# 18            8                509               of
#
#                   predicted_next_word  top_k_word_prediction  \
# 0                        [ ,  of,  (]                   True
# 1                         [ ,  i,  o]                   True
# 2                         [ ,  s,  t]                  False
# 3                           [ ,  , .]                   True
# 4   [ jurisdiction,  authority,  pur]                   True
# 5                       [ of, ,,  to]                   True
# 6                         [,, .,  of]                  False
# 7                        [st,  2,  1]                  False
# 8                 [ ,  health,  care]                  False
# 9                         [)(, ), ),]                   True
# 10                      [ 18,  ,  13]                   True
# 11                          [ ,  , .]                   True
# 12                          [ ,  , .]                   True
# 13                      [iii, iv, ii]                   True
# 14                       [95, 96, 94]                   True
# 15                   [ the,  end,  a]                   True
# 16                   [ are,  ,  have]                   True
# 17                          [., ., ,]                   True
# 18                   [ of,  and,  is]                   True
#
#     top_word_prediction
# 0                  True
# 1                  True
# 2                 False
# 3                  True
# 4                  True
# 5                  True
# 6                 False
# 7                 False
# 8                 False
# 9                  True
# 10                False
# 11                 True
# 12                 True
# 13                 True
# 14                False
# 15                 True
# 16                 True
# 17                 True
# 18                 True
# Bill 8 accuracy: 68.42%
#
# Bill 8 top k accuracy: 78.95%
#
# Processing bill 9 of length 2863 characters...
#     bill_number  input_text_length actual_next_word  \
# 0             9                 15                u
# 1             9                 55
# 2             9                 78                r
# 3             9                 98                ;
# 4             9                126            short
# 5             9                153          general
# 6             9                180       facilities
# 7             9                204              any
# 8             9                227
# 9             9                264    environmental
# 10            9                286                —
# 11            9                324             that
# 12            9                357                c
# 13            9                378
# 14            9                398              for
# 15            9                420                d
# 16            9                446              col
# 17            9                473              the
# 18            9                509            right
#
#                           predicted_next_word  top_k_word_prediction  \
# 0                               [ives, i,  1]                  False
# 1                                  [ , \n,  ]                   True
# 2                               [title,  , r]                  False
# 3                           [ a,  the,  from]                  False
# 4                                [ , 1,  The]                  False
# 5                  [ the,  this,  accordance]                  False
# 6    [ pipelines,  transportation,  pipeline]                  False
# 7                             [ the,  any, ,]                   True
# 8                                  [ ,  5, 5]                   True
# 9         [ environmental,  pipeline,  final]                   True
# 10                        [ the,  this,  all]                  False
# 11                            [ that,  or, ,]                   True
# 12                                 [c,  c, C]                   True
# 13                                [ ,  (,  5]                   True
# 14                            [ to,  that, ,]                  False
# 15                                  [d, 2, 4]                   True
# 16             [ Nebraska,  Columbia,  Omaha]                  False
# 17                            [ the,  a,  an]                   True
# 18  [ authorization,  approval,  authorizing]                  False
#
#     top_word_prediction
# 0                 False
# 1                  True
# 2                 False
# 3                 False
# 4                 False
# 5                 False
# 6                 False
# 7                 False
# 8                  True
# 9                  True
# 10                False
# 11                 True
# 12                 True
# 13                 True
# 14                False
# 15                 True
# 16                False
# 17                 True
# 18                False
# Bill 9 accuracy: 42.11%
#
# Bill 9 top k accuracy: 47.37%
#
# Processing bill 10 of length 845 characters...
#    bill_number  input_text_length actual_next_word  \
# 0           10                 15              res
# 1           10                 55          respect
# 2           10                 78                6
# 3           10                 98        committee
# 4           10                126               10
# 5           10                153                ,
# 6           10                180              for
#
#                      predicted_next_word  top_k_word_prediction  \
# 0                            [o,  ,  re]                  False
# 1              [ respect,  regard,  the]                   True
# 2                           [ 6,  7,  5]                   True
# 3  [ committee,  Committee,  committees]                   True
# 4                         [ 10,  9,  11]                   True
# 5                         [.,  and,  of]                  False
# 6                       [ to,  for,  so]                   True
#
#    top_word_prediction
# 0                False
# 1                 True
# 2                 True
# 3                 True
# 4                 True
# 5                False
# 6                False
# Bill 10 accuracy: 57.14%
#
# Bill 10 top k accuracy: 71.43%
#
# Processing bill 11 of length 3764 characters...
#     bill_number  input_text_length actual_next_word  \
# 0            11                 15                u
# 1            11                 55           public
# 2            11                 78              the
# 3            11                 98              the
# 4            11                126            child
# 5            11                153       collection
# 6            11                180               re
# 7            11                204                .
# 8            11                227
# 9            11                264          payment
# 10           11                286           ection
# 11           11                324           except
# 12           11                357               )(
# 13           11                378          payment
# 14           11                398                u
# 15           11                420              the
# 16           11                446                )
# 17           11                473         expended
# 18           11                509                4
#
#                    predicted_next_word  top_k_word_prediction  \
# 0                           [,,  (, .]                  False
# 1         [ public,  Public,  custody]                   True
# 2                    [ the, :,  title]                   True
# 3                    [ the,  bill,  a]                   True
# 4          [ child,  payments,  bills]                   True
# 5   [ bill,  collection,  enforcement]                   True
# 6                          [re, b, me]                   True
# 7                           [.,  s, d]                   True
# 8                         [ ,  ",  ``]                   True
# 9               [ child,  unpaid,  ar]                  False
# 10                   [ with,  to,  in]                  False
# 11                        [ (,  in, ,]                  False
# 12                         [), )(, ).]                   True
# 13          [ payment,  payments,  in]                   True
# 14                         [ u,  U, )]                   True
# 15                    [ the,  end,  a]                   True
# 16                          [), )(, .]                   True
# 17      [ credited,  deposited,  paid]                  False
# 18                        [ 4,  5,  6]                   True
#
#     top_word_prediction
# 0                 False
# 1                  True
# 2                  True
# 3                  True
# 4                  True
# 5                 False
# 6                  True
# 7                  True
# 8                  True
# 9                 False
# 10                False
# 11                False
# 12                False
# 13                 True
# 14                 True
# 15                 True
# 16                 True
# 17                False
# 18                 True
# Bill 11 accuracy: 63.16%
#
# Bill 11 top k accuracy: 73.68%
#
# Processing bill 12 of length 23184 characters...
#     bill_number  input_text_length actual_next_word  \
# 0            12                 15
# 1            12                 55               ak
# 2            12                 78              the
# 3            12                 98
# 4            12                126          ricting
# 5            12                153
# 6            12                180        authority
# 7            12                204         fairness
# 8            12                227               it
# 9            12                264               of
# 10           12                286               to
# 11           12                324               of
# 12           12                357           teenth
# 13           12                378
# 14           12                398
# 15           12                420          ricting
# 16           12                446              ala
# 17           12                473                s
# 18           12                509
#
#                 predicted_next_word  top_k_word_prediction  \
# 0                      [ ,  of,  (]                   True
# 1                        [., ia, t]                  False
# 2                    [ ,  the,  by]                   True
# 3                         [ ,  , �]                   True
# 4            [ricting, rict, ribut]                   True
# 5                    [ and,  to,  ]                   True
# 6           [ ,  amendment,  error]                  False
# 7              [ ",  ``,  National]                  False
# 8                  [ the,  ,  this]                  False
# 9                    [ of, .,  and]                   True
# 10               [ by,  to,  under]                   True
# 11                    [ of,  ,  in]                   True
# 12            [teenth, -,  hundred]                   True
# 13          [ the,  that,  section]                  False
# 14                 [ ,  members,  ]                   True
# 15          [ricting, rict, ortion]                   True
# 16                  [ar, uel, mart]                  False
# 17                       [ s, s, S]                   True
# 18  [ app,  election,  application]                  False
#
#     top_word_prediction
# 0                  True
# 1                 False
# 2                 False
# 3                  True
# 4                  True
# 5                 False
# 6                 False
# 7                 False
# 8                 False
# 9                  True
# 10                False
# 11                 True
# 12                 True
# 13                False
# 14                 True
# 15                 True
# 16                False
# 17                False
# 18                False
# Bill 12 accuracy: 42.11%
#
# Bill 12 top k accuracy: 63.16%
#
# Processing bill 13 of length 4446 characters...
#     bill_number  input_text_length actual_next_word  \
# 0            13                 15              res
# 1            13                 55       concurrent
# 2            13                 78              iet
# 3            13                 98
# 4            13                126                ;
# 5            13                153           result
# 6            13                180          whereas
# 7            13                204              the
# 8            13                227       accounting
# 9            13                264               11
# 10           13                286               be
# 11           13                324        president
# 12           13                357        immediate
# 13           13                378              iet
# 14           13                398                v
# 15           13                420               ve
# 16           13                446              nam
# 17           13                473                v
# 18           13                509           namese
#
#            predicted_next_word  top_k_word_prediction  top_word_prediction
# 0                 [ ,  of,  s]                  False                False
# 1                   [ ,  m, .]                  False                False
# 2                 [iet, iv, .]                   True                 True
# 3                [ The, \n,  ]                   True                False
# 4                 [,,  and, .]                  False                False
# 5       [ be,  continue,  not]                  False                False
# 6             [ ,  ,  whereas]                   True                False
# 7          [ the,  all,  both]                   True                 True
# 8           [ the,  its,  all]                  False                False
# 9                 [03, 02, 04]                  False                False
# 10        [ be,  not,  remain]                   True                 True
# 11     [ the,  on,  President]                   True                False
# 12      [ the,  a,  detention]                  False                False
# 13               [iet, ie, ia]                   True                 True
# 14      [ captivity,  v,  the]                   True                False
# 15  [ uncertain,  other,  way]                  False                False
# 16            [nam, namese, n]                   True                 True
# 17          [ the,  v,  there]                   True                False
# 18            [nam, namese, n]                   True                False
# Bill 13 accuracy: 26.32%
#
# Bill 13 top k accuracy: 57.89%
#
# Processing bill 14 of length 2984 characters...
#     bill_number  input_text_length actual_next_word  \
# 0            14                 15               of
# 1            14                 55               in
# 2            14                 78            house
# 3            14                 98              the
# 4            14                126
# 5            14                153                1
# 6            14                180             body
# 7            14                204           agency
# 8            14                227      prescribing
# 9            14                264                3
# 10           14                286              alf
# 11           14                324                b
# 12           14                357             that
# 13           14                378       compliance
# 14           14                398            grant
# 15           14                420                a
# 16           14                446             with
# 17           14                473                (
# 18           14                509            bring
#
#                         predicted_next_word  top_k_word_prediction  \
# 0                                [ i, i, a]                  False
# 1             [ hereby,  for,  copyrighted]                  False
# 2                [ United,  senate,  House]                   True
# 3                  [ the,  committee,  and]                   True
# 4                           [ ,  114,  112]                   True
# 5                             [ ,  The,  i]                  False
# 6                          [ in,  a,  body]                   True
# 7                    [ agency,  officer,  ]                   True
# 8   [ requiring,  implementing,  enforcing]                  False
# 9                               [ ,  3,  4]                   True
# 10                           [ality, is, a]                  False
# 11                               [b, 2, ii]                   True
# 12                       [ under,  that, ,]                   True
# 13                             [the, a, if]                  False
# 14              [ grant,  program,  waiver]                   True
# 15                             [ a,  an, ,]                   True
# 16                         [ with, .,  and]                   True
# 17                             [ (,  b,  a]                   True
# 18                    [ file,  sue,  bring]                   True
#
#     top_word_prediction
# 0                 False
# 1                 False
# 2                 False
# 3                  True
# 4                  True
# 5                 False
# 6                 False
# 7                  True
# 8                 False
# 9                 False
# 10                False
# 11                 True
# 12                False
# 13                False
# 14                 True
# 15                 True
# 16                 True
# 17                 True
# 18                False
# Bill 14 accuracy: 42.11%
#
# Bill 14 top k accuracy: 68.42%
#
# Overall accuracy for all bills: 50.92%
# Overall topk accuracy for all bills: 65.57%

# %%
#### Fine Tuning ####

# %%
from datasets import load_dataset
from transformers import GPT2Tokenizer, GPT2LMHeadModel, Trainer, TrainingArguments, DataCollatorForLanguageModeling
from datasets import Dataset
from torch.utils.data import DataLoader

# %%
cleaned_train = clean_text(dataset["train"]["text"][:60])
os.environ["WANDB_DISABLED"] = "true"

# %%
# Custom function to generate chunks from documents
def generate_chunks_from_text(text, min_length=100, max_length=512, tokenizer = tokenizer):
    tokens = tokenizer.encode(text, truncation=False, padding=False)  # Encode without truncation
    chunks = []
    while len(tokens) >= min_length:
        chunk_length = 512 #random.randint(min_length, min(max_length, len(tokens)))  # Random length for each chunk
        chunk = tokens[:chunk_length]
        chunks.append(chunk)
        tokens = tokens[chunk_length:]
    print("Generated n chunks: ", len(chunks))
    return chunks

# Function to manually expand the dataset by adding multiple rows for each document
def split_into_chunks(train_bills, min_length=100, max_length=512, tokenizer=tokenizer):
    all_input_ids = []
    all_labels = []
    all_attention_masks = []  # To store attention masks

    for text in train_bills:
        # Split the document into multiple chunks
        chunks = generate_chunks_from_text(text, min_length, max_length, tokenizer)
        for chunk in chunks:
            all_input_ids.append(chunk)
            all_labels.append(chunk)  # For causal language modeling, labels are the same as input_ids

            # Generate attention mask: 1 for real tokens, 0 for padding (for now, we assume no padding in chunks)
            attention_mask = [1] * len(chunk)
            all_attention_masks.append(attention_mask)

    print("Raw input ids and label ids dims:", len(all_input_ids), " x ", len(all_input_ids[0]), " or ", len(all_input_ids[1]), ' and ', len(all_labels), ' x ', len(all_labels[0]), ' or ', len(all_labels[1]))

    input_ids_padded = tokenizer.pad(
        {"input_ids": all_input_ids},  
        padding='max_length',  
        max_length=max_length, 
        return_tensors="pt"  
    )
    labels_padded = tokenizer.pad(
        {"input_ids": all_labels}, 
        padding='max_length',
        max_length=max_length,
        return_tensors="pt"
    )
    attention_masks_padded = tokenizer.pad(
        {"input_ids": all_attention_masks}, 
        padding='max_length',
        max_length=max_length,
        return_tensors="pt"
    )
    print("In split into chunks, size of all 3 columns: ", input_ids_padded['input_ids'].shape)
    return {
        "input_ids": input_ids_padded["input_ids"],
       # "labels": labels_padded["input_ids"],
       # "attention_mask": attention_masks_padded["input_ids"]  # Add the attention mask
    }

# Function to train the model with explicit parameters
def train_model(clean_tr, clean_val, tokenizer, model, epochs=3, output_dir="./drive/MyDrive/nlp_proj_results"):
    train_bills = clean_tr
    val_bills = clean_val

    tokenizer.pad_token = tokenizer.eos_token

    train_dataset = Dataset.from_dict({"text": train_bills})
    train_dataset = Dataset.from_dict(split_into_chunks(train_bills, min_length=100, max_length=512))
    #print("Train dataset size: ", train_dataset['input_ids'].shape)
    print("Train dataset: ", train_dataset)
    data_collator = DataCollatorForLanguageModeling(
      tokenizer=tokenizer,
      mlm=False  # This is not a masked language model task, so set to False
    )

    training_args = TrainingArguments(
        output_dir=output_dir,
        num_train_epochs=epochs,
        max_grad_norm=1.0,
        logging_dir="./logs",
        logging_steps=100,
    )

    trainer = Trainer(
        model=model,
        args=training_args,
        data_collator=data_collator,
        train_dataset=train_dataset,
    )

    trainer.train()

    model.save_pretrained(output_dir)
    return model

# %%
#torch.cuda.empty_cache()
fine_tuned_gpt2 = train_model(cleaned_train, cleaned_validation, tokenizer, model, epochs=10)
# Out:
# I be
# Doubting
# Generated n chunks:  2
# I be
# Doubting
# Generated n chunks:  3
# I be
# Doubting
# Generated n chunks:  1
# I be
# Doubting
# Generated n chunks:  1
# I be
# Doubting
# Generated n chunks:  3
# I be
# Doubting
# Generated n chunks:  2
# I be
# Doubting
# Generated n chunks:  2
# I be
# Doubting
# Generated n chunks:  2
# I be
# Doubting
# Generated n chunks:  3
# I be
# Doubting
# Generated n chunks:  5
# I be
# Doubting
# Generated n chunks:  1
# I be
# Doubting
# Generated n chunks:  5
# I be
# Doubting
# Generated n chunks:  2
# I be
# Doubting
# Generated n chunks:  8
# I be
# Doubting
# Generated n chunks:  1
# I be
# Doubting
# Generated n chunks:  4
# I be
# Doubting
# Generated n chunks:  1
# I be
# Doubting
# Generated n chunks:  1
# I be
# Doubting
# Generated n chunks:  2
# I be
# Doubting
# Generated n chunks:  3
# I be
# Doubting
# Generated n chunks:  2
# I be
# Doubting
# Generated n chunks:  5
# I be
# Doubting
# Generated n chunks:  3
# I be
# Doubting
# Generated n chunks:  1
# I be
# Doubting
# Generated n chunks:  2
# I be
# Doubting
# Generated n chunks:  2
# I be
# Doubting
# Generated n chunks:  13
# I be
# Doubting
# Generated n chunks:  1
# I be
# Doubting
# Generated n chunks:  4
# I be
# Doubting
# Generated n chunks:  2
# I be
# Doubting
# Generated n chunks:  3
# I be
# Doubting
# Generated n chunks:  1
# I be
# Doubting
# Generated n chunks:  4
# I be
# Doubting
# Generated n chunks:  3
# I be
# Doubting
# Generated n chunks:  2
# I be
# Doubting
# Generated n chunks:  2
# I be
# Doubting
# Generated n chunks:  4
# I be
# Doubting
# Generated n chunks:  3
# I be
# Doubting
# Generated n chunks:  1
# I be
# Doubting
# Generated n chunks:  3
# I be
# Doubting
# Generated n chunks:  3
# I be
# Doubting
# Generated n chunks:  4
# I be
# Doubting
# Generated n chunks:  1
# I be
# Doubting
# Generated n chunks:  1
# I be
# Doubting
# Generated n chunks:  1
# I be
# Doubting
# Generated n chunks:  1
# I be
# Doubting
# Generated n chunks:  1
# I be
# Doubting
# Generated n chunks:  2
# I be
# Doubting
# Generated n chunks:  45
# I be
# Doubting
# Generated n chunks:  2
# I be
# Doubting
# Generated n chunks:  1
# I be
# Doubting
# Generated n chunks:  11
# I be
# Doubting
# Generated n chunks:  2
# I be
# Doubting
# Generated n chunks:  6
# I be
# Doubting
# Generated n chunks:  2
# I be
# Doubting
# Generated n chunks:  1
# I be
# Doubting
# Generated n chunks:  15
# I be
# Doubting
# Generated n chunks:  2
# I be
# Doubting
# Generated n chunks:  12
# I be
# Doubting
# Generated n chunks:  1
# Raw input ids and label ids dims: 227  x  512  or  512  and  227  x  512  or  512
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# In split into chunks, size of all 3 columns:  torch.Size([227, 512])
# Train dataset:  Dataset({
#     features: ['input_ids'],
#     num_rows: 227
# })
# /Users/urvimidha/anaconda3/lib/python3.11/site-packages/transformers/optimization.py:407: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='290' max='290' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [290/290 4:28:51, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>2.117300</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.710900</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
df_predictions_bills_finetuned = evaluate_bills(cleaned_validation, model=fine_tuned_gpt2)
# Out:
# Processing bill 0 of length 6705 characters...
#     bill_number  input_text_length actual_next_word  \
# 0             0                 15              act
# 1             0                 55              the
# 2             0                 78              the
# 3             0                 98                (
# 4             0                126             penn
# 5             0                153               of
# 6             0                180               of
# 7             0                204                m
# 8             0                227                .
# 9             0                264                m
# 10            0                286                h
# 11            0                324                .
# 12            0                357                ,
# 13            0                378                .
# 14            0                398                ,
# 15            0                420             love
# 16            0                446              aff
# 17            0                473        judiciary
# 18            0                509     jurisdiction
#
#                         predicted_next_word  top_k_word_prediction  \
# 0                            [ ,  act,  of]                   True
# 1                          [ the, the,  an]                   True
# 2                 [ the,  house,  congress]                   True
# 3                      [ introduced,  (, ,]                   True
# 4                           [ cal,  fl,  m]                  False
# 5                               [,,  of, )]                   True
# 6                             [ of, ,, son]                   True
# 7                           [ m,  and,  ms]                   True
# 8                                [., .., ,]                   True
# 9                           [ m,  ms,  and]                   True
# 10                      [ bart,  sch,  lou]                  False
# 11                               [., .., ,]                   True
# 12                           [,,  of,  and]                   True
# 13                               [., .., ,]                   True
# 14                               [,, ), ),]                   True
# 15                            [ g,  k,  ro]                  False
# 16                             [af, u, apt]                  False
# 17      [ judiciary,  Judiciary,  commerce]                   True
# 18  [ jurisdiction,  authority,  committee]                   True
#
#     top_word_prediction
# 0                 False
# 1                  True
# 2                  True
# 3                 False
# 4                 False
# 5                 False
# 6                  True
# 7                  True
# 8                  True
# 9                  True
# 10                False
# 11                 True
# 12                 True
# 13                 True
# 14                 True
# 15                False
# 16                False
# 17                 True
# 18                 True
# Bill 0 accuracy: 63.16%
#
# Bill 0 top k accuracy: 78.95%
#
# Processing bill 1 of length 48228 characters...
#     bill_number  input_text_length actual_next_word  \
# 0             1                 15              the
# 1             1                 55              the
# 2             1                 78                i
# 3             1                 98           united
# 4             1                126           second
# 5             1                153
# 6             1                180           budget
# 7             1                204              for
# 8             1                227                (
# 9             1                264                1
# 10            1                286              ary
# 11            1                324              201
# 12            1                357                .
# 13            1                378            effic
# 14            1                398          savings
# 15            1                420              500
# 16            1                446                .
# 17            1                473         determin
# 18            1                509           levels
#
#              predicted_next_word  top_k_word_prediction  top_word_prediction
# 0         [ the,  fiscal,  2018]                   True                 True
# 1            [ the,  title, the]                   True                 True
# 2                   [ ,  ii,  i]                   True                False
# 3     [ united,  senate,  house]                   True                 True
# 4        [ next,  bill,  second]                   True                False
# 5                  [ ,  for,  u]                   True                 True
# 6               [short, to, def]                  False                False
# 7                 [ for,  of,  ]                   True                 True
# 8                    [ ,  (,  2]                   True                False
# 9                      [1, 2, 3]                   True                 True
# 10             [ for, for,  and]                  False                False
# 11               [103, 201, 105]                   True                False
# 12                    [., .., a]                   True                 True
# 13  [ fiscal,  seniors,  senate]                  False                False
# 14      [ care,  benefits,  and]                  False                False
# 15             [ 500,  501,  50]                   True                 True
# 16                    [., .., —]                   True                 True
# 17              [ of,  in,  and]                  False                False
# 18                 [.,  by,  in]                  False                False
# Bill 1 accuracy: 47.37%
#
# Bill 1 top k accuracy: 68.42%
#
# Processing bill 2 of length 4566 characters...
#     bill_number  input_text_length actual_next_word  \
# 0             2                 15              and
# 1             2                 55              and
# 2             2                 78          session
# 3             2                 98
# 4             2                126
# 5             2                153              and
# 6             2                180             with
# 7             2                204
# 8             2                227          service
# 9             2                264              the
# 10            2                286
# 11            2                324
# 12            2                357              and
# 13            2                378       subsection
# 14            2                398
# 15            2                420               be
# 16            2                446              the
# 17            2                473             with
# 18            2                509          dentist
#
#                 predicted_next_word  top_k_word_prediction  \
# 0              [ and, ,,  services]                   True
# 1                     [ and,  &,  ]                   True
# 2        [ session,  sessions,  hr]                   True
# 3                       [ ,  1,  m]                   True
# 4                       [ ,  u,  (]                   True
# 5                  [ and,  ,  care]                   True
# 6                 [ that,  in,  of]                  False
# 7                  [ ,  the,  such]                   True
# 8   [ education,  dental,  hygiene]                  False
# 9             [the, there, section]                   True
# 10                 [ ,  the,  such]                   True
# 11                  [ ,  that,  in]                   True
# 12                   [ and,  ,  or]                   True
# 13       [ the,  this,  subsection]                   True
# 14                      [ ,  (,  3]                   True
# 15                      [ be, —,  ]                   True
# 16                  [ the,  a,  an]                   True
# 17                      [ by,  , )]                  False
# 18           [ dentist,  dental,  ]                   True
#
#     top_word_prediction
# 0                  True
# 1                  True
# 2                  True
# 3                  True
# 4                  True
# 5                  True
# 6                 False
# 7                  True
# 8                 False
# 9                  True
# 10                 True
# 11                 True
# 12                 True
# 13                False
# 14                 True
# 15                 True
# 16                 True
# 17                False
# 18                 True
# Bill 2 accuracy: 78.95%
#
# Bill 2 top k accuracy: 84.21%
#
# Processing bill 3 of length 3199 characters...
#     bill_number  input_text_length actual_next_word  \
# 0             3                 15
# 1             3                 55                ,
# 2             3                 78                .
# 3             3                 98
# 4             3                126
# 5             3                153
# 6             3                180
# 7             3                204                a
# 8             3                227         security
# 9             3                264
# 10            3                286       protection
# 11            3                324           issued
# 12            3                357
# 13            3                378                c
# 14            3                398              end
# 15            3                420               of
# 16            3                446
# 17            3                473          include
# 18            3                509
#
#                  predicted_next_word  top_k_word_prediction  \
# 0                        [ ,  h,  s]                   True
# 1                       [,,  and,  ]                   True
# 2                         [., .., s]                   True
# 3                      [ ,  m,  and]                   True
# 4          [ ,  legislation,  bills]                   True
# 5                      [ ,  m,  the]                   True
# 6                      [ ,  the,  i]                   True
# 7                       [ ,  and, �]                  False
# 8   [ security,  safety,  insurance]                   True
# 9                      [ ,  the,  1]                   True
# 10               [ and,  of,  theft]                  False
# 11                    [ ,  (,  used]                  False
# 12                      [ ,  (,  of]                   True
# 13                      [c,  c,  53]                   True
# 14        [ end,  beginning,  start]                   True
# 15                      [ of,  , 's]                   True
# 16                     [ ,  on,  in]                   True
# 17          [ title,  any,  benefit]                  False
# 18                       [ ,  (,  2]                   True
#
#     top_word_prediction
# 0                  True
# 1                  True
# 2                  True
# 3                  True
# 4                  True
# 5                  True
# 6                  True
# 7                 False
# 8                  True
# 9                  True
# 10                False
# 11                False
# 12                 True
# 13                 True
# 14                 True
# 15                 True
# 16                 True
# 17                False
# 18                 True
# Bill 3 accuracy: 78.95%
#
# Bill 3 top k accuracy: 78.95%
#
# Processing bill 4 of length 7822 characters...
#     bill_number  input_text_length actual_next_word  \
# 0             4                 15                (
# 1             4                 55        liability
# 2             4                 78            trade
# 3             4                 98            other
# 4             4                126                5
# 5             4                153              for
# 6             4                180              the
# 7             4                204              117
# 8             4                227                j
# 9             4                264              oro
# 10            4                286              for
# 11            4                324        equitable
# 12            4                357             ghan
# 13            4                378              for
# 14            4                398              the
# 15            4                420        designate
# 16            4                446                .
# 17            4                473        committee
# 18            4                509          amended
#
#                     predicted_next_word  top_k_word_prediction  \
# 0                           [ to,  , ;]                  False
# 1      [ enforcement,  remed,  control]                  False
# 2   [ environmental,  disaster,  toxic]                  False
# 3         [ other,  cert,  enforcement]                   True
# 4                             [), 4, 3]                  False
# 5                 [ for,  to,  provide]                   True
# 6                 [ the,  title,  this]                   True
# 7                           [ , ., 117]                  False
# 8                          [ ,  (,  in]                  False
# 9                          [oro, or, o]                   True
# 10                     [ for,  that, ,]                   True
# 11  [ equitable,  appropriate,  equity]                   True
# 12                        [ghan, ga, g]                   True
# 13                  [ for,  other,  to]                   True
# 14         [ the,  detail,  accordance]                   True
# 15    [ designate,  appoint,  identify]                   True
# 16                            [;, ., ,]                   True
# 17                 [,,  and,  proposed]                  False
# 18         [ so,  amended,  introduced]                   True
#
#     top_word_prediction
# 0                 False
# 1                 False
# 2                 False
# 3                  True
# 4                 False
# 5                  True
# 6                  True
# 7                 False
# 8                 False
# 9                  True
# 10                 True
# 11                 True
# 12                 True
# 13                 True
# 14                 True
# 15                 True
# 16                False
# 17                False
# 18                False
# Bill 4 accuracy: 52.63%
#
# Bill 4 top k accuracy: 63.16%
#
# Processing bill 5 of length 5447 characters...
#     bill_number  input_text_length actual_next_word  \
# 0             5                 15               of
# 1             5                 55                u
# 2             5                 78              the
# 3             5                 98
# 4             5                126             city
# 5             5                153
# 6             5                180              the
# 7             5                204               me
# 8             5                227             most
# 9             5                264             1994
# 10            5                286               of
# 11            5                324           united
# 12            5                357              can
# 13            5                378             host
# 14            5                398              the
# 15            5                420             have
# 16            5                446               20
# 17            5                473           states
# 18            5                509           sports
#
#                predicted_next_word  top_k_word_prediction  top_word_prediction
# 0                [ of,  made,  to]                   True                 True
# 1                      [ ,  u,  h]                   True                False
# 2             [ the,  title,  law]                   True                 True
# 3                   [ ,  d,  This]                   True                 True
# 4    [ house,  residence,  office]                  False                False
# 5                    [th,  is,  (]                  False                False
# 6                  [ the,  can,  ]                   True                 True
# 7               [ ,  united,  and]                  False                False
# 8      [ most,  fastest,  largest]                   True                 True
# 9              [ f,  2018,  world]                  False                False
# 10                  [ for, ,,  of]                   True                False
# 11     [ united,  world,  country]                   True                 True
# 12           [ other,  the,  many]                  False                False
# 13              [ the,  host,  be]                   True                False
# 14            [ the,  united,  me]                   True                 True
# 15      [ the,  respect,  promote]                  False                False
# 16  [ united,  congress,  federal]                  False                False
# 17      [ states,  state,  people]                   True                 True
# 18    [ soccer,  leagues,  sports]                   True                False
# Bill 5 accuracy: 42.11%
#
# Bill 5 top k accuracy: 63.16%
#
# Processing bill 6 of length 8875 characters...
#     bill_number  input_text_length  actual_next_word  \
# 0             6                 15
# 1             6                 55               the
# 2             6                 78                 .
# 3             6                 98
# 4             6                126   representatives
# 5             6                153                 a
# 6             6                180
# 7             6                204          national
# 8             6                227             north
# 9             6                264             about
# 10            6                286                 ;
# 11            6                324
# 12            6                357               the
# 13            6                378
# 14            6                398               the
# 15            6                420             peace
# 16            6                446         involving
# 17            6                473       declaration
# 18            6                509            rights
#
#                   predicted_next_word  top_k_word_prediction  \
# 0         [ representatives,  the,  ]                   True
# 1                     [ the,  its,  ]                   True
# 2                        [.,  18, 18]                   True
# 3                     [ ,  jan,  apr]                   True
# 4    [ representatives,  congress,  ]                   True
# 5                  [ a,  ,  refugees]                   True
# 6                         [ ,  (,  u]                   True
# 7   [ ethnic,  cultural,  linguistic]                  False
# 8            [ whereas,  and,  while]                  False
# 9               [ for,  about,  over]                   True
# 10                        [;,  in, ,]                   True
# 11                        [ ,  (,  u]                   True
# 12                [ the,  this,  all]                   True
# 13                      [ ,  the,  a]                   True
# 14          [ the,  north,  northern]                   True
# 15      [ and,  plan,  international]                  False
# 16                        [,, ;,  to]                  False
# 17         [ beginning,  end,  start]                  False
# 18          [ human,  rights,  civil]                   True
#
#     top_word_prediction
# 0                 False
# 1                  True
# 2                  True
# 3                  True
# 4                  True
# 5                  True
# 6                  True
# 7                 False
# 8                 False
# 9                 False
# 10                 True
# 11                 True
# 12                 True
# 13                 True
# 14                 True
# 15                False
# 16                False
# 17                False
# 18                False
# Bill 6 accuracy: 57.89%
#
# Bill 6 top k accuracy: 73.68%
#
# Processing bill 7 of length 8487 characters...
#     bill_number  input_text_length actual_next_word  \
# 0             7                 15
# 1             7                 55          himself
# 2             7                 78
# 3             7                 98         homeland
# 4             7                126
# 5             7                153
# 6             7                180                .
# 7             7                204                (
# 8             7                227
# 9             7                264            after
# 10            7                286                )
# 11            7                324
# 12            7                357                .
# 13            7                378
# 14            7                398               to
# 15            7                420                7
# 16            7                446                (
# 17            7                473                )
# 18            7                509                c
#
#              predicted_next_word  top_k_word_prediction  top_word_prediction
# 0                    [ ,  h,  s]                   True                 True
# 1              [ m,  ,  himself]                   True                False
# 2        [ ,  bill,  resolution]                   True                 True
# 3   [ foreign,  banking,  armed]                  False                False
# 4                    [ ,  (,  �]                   True                 True
# 5                    [ ,  1,  i]                   True                 True
# 6                    [., .., .(]                   True                 True
# 7           [ (,  is,  provides]                   True                 True
# 8                   [ ,  (,  of]                   True                 True
# 9                  [ ,  the,  (]                  False                False
# 10                    [), )(, .]                   True                 True
# 11                 [ ,  (,  and]                   True                 True
# 12                    [., .., ,]                   True                 True
# 13                  [ ,  (,  to]                   True                 True
# 14      [ and,  but,  including]                  False                False
# 15             [ the,  a,  that]                  False                False
# 16                   [ (,  ,  b]                   True                 True
# 17                   [), )(, ).]                   True                 True
# 18                   [c,  c, ca]                   True                 True
# Bill 7 accuracy: 73.68%
#
# Bill 7 top k accuracy: 78.95%
#
# Processing bill 8 of length 16413 characters...
#     bill_number  input_text_length actual_next_word  \
# 0             8                 15
# 1             8                 55
# 2             8                 78            means
# 3             8                 98
# 4             8                126     jurisdiction
# 5             8                153               of
# 6             8                180               by
# 7             8                204                .
# 8             8                227        standards
# 9             8                264               )(
# 10            8                286               13
# 11            8                324
# 12            8                357
# 13            8                378              iii
# 14            8                398               96
# 15            8                420              the
# 16            8                446              are
# 17            8                473                .
# 18            8                509               of
#
#            predicted_next_word  top_k_word_prediction  top_word_prediction
# 0                   [ ,  h, h]                   True                 True
# 1                 [ ,  (,  of]                   True                 True
# 2           [ ,  means,  ways]                   True                False
# 3                [ ,  the,  a]                   True                 True
# 4   [ ,  jurisdiction,  sense]                   True                False
# 5                [ of,  to, ,]                   True                 True
# 6                  [,,  of, ;]                  False                False
# 7                   [., st,  ]                   True                 True
# 8         [ ,  care,  patient]                  False                False
# 9                  [), )(, ),]                   True                False
# 10               [ 14,  13,  ]                   True                False
# 11              [ to,  ,  for]                   True                False
# 12          [ ,  manner,  way]                   True                 True
# 13               [iii, iv, ii]                   True                 True
# 14                [95, 90, 94]                  False                False
# 15            [ the,  end,  a]                   True                 True
# 16            [ are,  ,  have]                   True                 True
# 17                  [., ), .(]                   True                 True
# 18              [ of,  is,  (]                   True                 True
# Bill 8 accuracy: 57.89%
#
# Bill 8 top k accuracy: 84.21%
#
# Processing bill 9 of length 2863 characters...
#     bill_number  input_text_length actual_next_word  \
# 0             9                 15                u
# 1             9                 55
# 2             9                 78                r
# 3             9                 98                ;
# 4             9                126            short
# 5             9                153          general
# 6             9                180       facilities
# 7             9                204              any
# 8             9                227
# 9             9                264    environmental
# 10            9                286                —
# 11            9                324             that
# 12            9                357                c
# 13            9                378
# 14            9                398              for
# 15            9                420                d
# 16            9                446              col
# 17            9                473              the
# 18            9                509            right
#
#                            predicted_next_word  top_k_word_prediction  \
# 0                              [ of, uary,  u]                   True
# 1                                 [ ,  ii,  i]                   True
# 2                                [ r,  res, r]                   True
# 3                              [ the,  a,  an]                  False
# 4                       [short, cong, closure]                   True
# 5                     [ general,  ,  generals]                   True
# 6   [ infrastructure,  transportation,  water]                  False
# 7                          [ the,  a,  design]                  False
# 8                                  [(, the,  ]                   True
# 9          [ environmental,  final,  proposed]                   True
# 10                          [ the,  all,  any]                  False
# 11                               [ or,  of, ,]                  False
# 12                                  [c, C,  c]                   True
# 13                                  [ ,  (, (]                   True
# 14                       [ under,  shall,  to]                  False
# 15                                   [d, 2, c]                   True
# 16                             [ col,  ,  tex]                   True
# 17                             [ the,  a,  an]                   True
# 18     [ authorization,  approval,  approvals]                  False
#
#     top_word_prediction
# 0                 False
# 1                  True
# 2                  True
# 3                 False
# 4                  True
# 5                  True
# 6                 False
# 7                 False
# 8                 False
# 9                  True
# 10                False
# 11                False
# 12                 True
# 13                 True
# 14                False
# 15                 True
# 16                 True
# 17                 True
# 18                False
# Bill 9 accuracy: 52.63%
#
# Bill 9 top k accuracy: 63.16%
#
# Processing bill 10 of length 845 characters...
#    bill_number  input_text_length actual_next_word  \
# 0           10                 15              res
# 1           10                 55          respect
# 2           10                 78                6
# 3           10                 98        committee
# 4           10                126               10
# 5           10                153                ,
# 6           10                180              for
#
#                         predicted_next_word  top_k_word_prediction  \
# 0                             [ r,  res, r]                   True
# 1                    [ respect,  ,  regard]                   True
# 2                              [ 6,  (,  7]                   True
# 3  [ committee,  committees,  subcommittee]                   True
# 4                             [ 10,  9,  8]                   True
# 5                           [ for, .,  and]                  False
# 6                            [ to,  for,  ]                   True
#
#    top_word_prediction
# 0                False
# 1                 True
# 2                 True
# 3                 True
# 4                 True
# 5                False
# 6                False
# Bill 10 accuracy: 57.14%
#
# Bill 10 top k accuracy: 85.71%
#
# Processing bill 11 of length 3764 characters...
#     bill_number  input_text_length actual_next_word  \
# 0            11                 15                u
# 1            11                 55           public
# 2            11                 78              the
# 3            11                 98              the
# 4            11                126            child
# 5            11                153       collection
# 6            11                180               re
# 7            11                204                .
# 8            11                227
# 9            11                264          payment
# 10           11                286           ection
# 11           11                324           except
# 12           11                357               )(
# 13           11                378          payment
# 14           11                398                u
# 15           11                420              the
# 16           11                446                )
# 17           11                473         expended
# 18           11                509                4
#
#                 predicted_next_word  top_k_word_prediction  \
# 0                      [ u,  of,  ]                   True
# 1   [ public,  interest,  improper]                   True
# 2              [ the,  congress,  ]                   True
# 3                     [ the,  ,  a]                   True
# 4     [ child,  payments,  federal]                   True
# 5    [ collection,  enforcement,  ]                   True
# 6                      [re, ri, ab]                   True
# 7                        [., s, ..]                   True
# 8                       [ ,  (,  4]                   True
# 9                [ child,  such,  ]                  False
# 10                   [ to, in,  in]                  False
# 11                    [ ,  at,  or]                  False
# 12                      [), )(, ).]                   True
# 13         [ payment,  payments,  ]                   True
# 14                     [ u,  r,  U]                   True
# 15            [ the,  ,  paragraph]                   True
# 16                      [), )(, ),]                   True
# 17        [ paid,  credited,  used]                  False
# 18                   [ 4,  8,  404]                   True
#
#     top_word_prediction
# 0                  True
# 1                  True
# 2                  True
# 3                  True
# 4                  True
# 5                  True
# 6                  True
# 7                  True
# 8                  True
# 9                 False
# 10                False
# 11                False
# 12                False
# 13                 True
# 14                 True
# 15                 True
# 16                 True
# 17                False
# 18                 True
# Bill 11 accuracy: 73.68%
#
# Bill 11 top k accuracy: 78.95%
#
# Processing bill 12 of length 23184 characters...
#     bill_number  input_text_length actual_next_word  \
# 0            12                 15
# 1            12                 55               ak
# 2            12                 78              the
# 3            12                 98
# 4            12                126          ricting
# 5            12                153
# 6            12                180        authority
# 7            12                204         fairness
# 8            12                227               it
# 9            12                264               of
# 10           12                286               to
# 11           12                324               of
# 12           12                357           teenth
# 13           12                378
# 14           12                398
# 15           12                420          ricting
# 16           12                446              ala
# 17           12                473                s
# 18           12                509
#
#              predicted_next_word  top_k_word_prediction  top_word_prediction
# 0                     [ ,  h, .]                   True                 True
# 1                [ol, avis, ale]                  False                False
# 2                   [ the,  , ,]                   True                 True
# 3                  [ ,  m,  the]                   True                 True
# 4           [ricting, rict, rav]                   True                 True
# 5                 [ ,  and,  to]                   True                 True
# 6   [ violations,  violation,  ]                  False                False
# 7           [ ,  state,  states]                  False                False
# 8             [ the,  states,  ]                  False                False
# 9                  [ of,  ,  or]                   True                 True
# 10            [ to,  by,  under]                   True                 True
# 11                 [ in,  of, ,]                   True                False
# 12            [teenth, -,  year]                   True                 True
# 13           [ the,  ,  section]                   True                False
# 14      [ ,  members,  congress]                   True                 True
# 15       [ricting, rict, ortion]                   True                 True
# 16                 [ar, iz, uel]                  False                False
# 17                    [s, c,  s]                   True                 True
# 18          [ app,  ,  election]                   True                False
# Bill 12 accuracy: 57.89%
#
# Bill 12 top k accuracy: 73.68%
#
# Processing bill 13 of length 4446 characters...
#     bill_number  input_text_length actual_next_word  \
# 0            13                 15              res
# 1            13                 55       concurrent
# 2            13                 78              iet
# 3            13                 98
# 4            13                126                ;
# 5            13                153           result
# 6            13                180          whereas
# 7            13                204              the
# 8            13                227       accounting
# 9            13                264               11
# 10           13                286               be
# 11           13                324        president
# 12           13                357        immediate
# 13           13                378              iet
# 14           13                398                v
# 15           13                420               ve
# 16           13                446              nam
# 17           13                473                v
# 18           13                509           namese
#
#               predicted_next_word  top_k_word_prediction  top_word_prediction
# 0                   [ res,  r,  ]                   True                 True
# 1                   [ ,  m,  and]                  False                False
# 2                   [iet, ik, iv]                   True                 True
# 3                 [ ,  which,  m]                   True                 True
# 4                    [,, .,  and]                  False                False
# 5   [ be,  strengthen,  continue]                  False                False
# 6             [ whereas,  ,  and]                   True                 True
# 7                [ the,  all,  v]                   True                 True
# 8       [ the,  its,  accordance]                  False                False
# 9                    [03, 04, 07]                  False                False
# 10           [ be,  not,  remain]                   True                 True
# 11                [ the,  v,  on]                  False                False
# 12             [ the,  a,  other]                  False                False
# 13                [iet, ita, ich]                   True                 True
# 14                 [ v,  the,  j]                   True                 True
# 15                 [ve, v,  less]                   True                 True
# 16              [nam, namese, ne]                   True                 True
# 17                 [ the,  v,  a]                   True                False
# 18               [nam, namese, n]                   True                False
# Bill 13 accuracy: 52.63%
#
# Bill 13 top k accuracy: 63.16%
#
# Processing bill 14 of length 2984 characters...
#     bill_number  input_text_length actual_next_word  \
# 0            14                 15               of
# 1            14                 55               in
# 2            14                 78            house
# 3            14                 98              the
# 4            14                126
# 5            14                153                1
# 6            14                180             body
# 7            14                204           agency
# 8            14                227      prescribing
# 9            14                264                3
# 10           14                286              alf
# 11           14                324                b
# 12           14                357             that
# 13           14                378       compliance
# 14           14                398            grant
# 15           14                420                a
# 16           14                446             with
# 17           14                473                (
# 18           14                509            bring
#
#                      predicted_next_word  top_k_word_prediction  \
# 0                         [ u,  no,  of]                   True
# 1                      [ in,  not,  for]                   True
# 2             [ house,  senate,  united]                   True
# 3                 [ the,  committee,  a]                   True
# 4              [ officers,  agencies,  ]                   True
# 5                            [ ,  1,  (]                   True
# 6                     [ in,  ,  cameras]                  False
# 7              [ agency,  ,  department]                   True
# 8   [ superv,  implementing,  requiring]                  False
# 9                            [ ,  3,  (]                   True
# 10                            [is, ., o]                  False
# 11                             [b, a, 2]                   True
# 12                    [ under,  that, ,]                   True
# 13            [report, definition, form]                  False
# 14              [ grant,  program,  law]                   True
# 15                       [ a,  an,  and]                   True
# 16                    [ with,  under, .]                   True
# 17                           [ (,  b,  ]                   True
# 18                  [ file,  bring,  be]                   True
#
#     top_word_prediction
# 0                 False
# 1                  True
# 2                  True
# 3                  True
# 4                 False
# 5                 False
# 6                 False
# 7                  True
# 8                 False
# 9                 False
# 10                False
# 11                 True
# 12                False
# 13                False
# 14                 True
# 15                 True
# 16                 True
# 17                 True
# 18                False
# Bill 14 accuracy: 47.37%
#
# Bill 14 top k accuracy: 78.95%
#
# Overall accuracy for all bills: 59.71%
# Overall topk accuracy for all bills: 73.99%
